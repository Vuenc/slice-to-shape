# %%
# %reload_ext autoreload
# %autoreload 2
# from ssm_thyroid_dataset import SSMvoxelDataset
from ssm_thyroid_dataset_originalmethod import NewSdfVoxelDataset
from train_ssmvoxel import train
import torch
import os
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
#segthy dataset
# us_dir = f"/home/dilab/dilab_data/data/subset_SegThy/left/US"
# sdf_dir = f"/home/dilab/dilab_data/data/data_ssmsdf" 

# us_index_range_train = range(0, 22)
# us_index_range_val = range(22, 25)

# us_paths_train = [f"{us_dir}/train/{str(us_index+1).zfill(3)}_P1_1_left_US.nii.gz" for us_index in us_index_range_train]
# us_paths_val = [f"{us_dir}/val/{str(us_index+1).zfill(3)}_P1_1_left_US.nii.gz" for us_index in us_index_range_val]


# # ############ train with only ori sdf ###################### 

# us_dir = f"/home/dilab/dilab_data/data"
# sdf_dir = f"/home/dilab/dilab_data/data/oridataset_sdf"

# us_index_range_train = range(0, 26, 2)
# us_index_range_val = range(26, 32 , 2)

# us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
# us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


# sdf_index_range_train = range(0, 13)
# sdf_index_range_val = range(13, 16)

# sdf_paths_train = [f"{sdf_dir}/sdf_train/{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
# sdf_paths_val = [f"{sdf_dir}/sdf_val/{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


# num_patches_per_thyroid = 300
# train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir}/sdf_train")
# val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir}/sdf_val")


################    original dataset      #####################

# 12 / 2 / 2 split

# us_dir = f"/home/dilab/dilab_data/data"
# sdf_dir = f"/home/dilab/dilab_data/data/data_ssmsdf"

# # sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.05/sdf_train"
# # sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

# us_index_range_train = range(0, 24, 2)
# us_index_range_val = range(24, 28 , 2)
 
# us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
# us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


# sdf_index_range_train = range(0, 500)
# sdf_index_range_val = range(0, 1)

# sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
# sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]

num_patches_per_thyroid = 512
us_grid_paths = ["/home/dilab/dilab_data/data/%d.nii" % i for i in range(0, 32, 2)]
sdf_grid_paths = [f"/home/dilab/dilab_data/data/sdf_data_dilab/data{i}/sdf" for i in range(0, 32, 2)]
mesh_paths = [f"/home/dilab/dilab_data/data/{i}.ply" for i in range(0, 32, 2)]
patch_files_dirs = [f"/home/dilab/dilab_data/data/sdf_data_dilab/data{i}/" for i in range(0, 32, 2)]
train_to = 12
val_to = 14

#train_dataset = NewSdfVoxelDataset(us_grid_paths[:train_to], sdf_grid_paths[:train_to], mesh_paths[:train_to],
#   num_patches_per_thyroid, ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32))
#val_dataset = NewSdfVoxelDataset(us_grid_paths[train_to:val_to], sdf_grid_paths[train_to:val_to], mesh_paths[train_to:val_to],
#    num_patches_per_thyroid, ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32))


# train_dataset = NewSdfVoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.2)
# val_dataset = NewSdfVoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.2)

# %%
# Experiment 2: different settings for thyroid-to-thyroid

# alphas: 1.0, 5.0, 2.5
# patch sizes: (32,32,32), (64,64,8), (128, 128, 2), (128, 128, 1)
# number of patches: 300, 600

for alpha, patch_shape, num_patches, batch_size in [
        (5.0, (128, 128, 1), 300, 150),
        (5.0, (32,32,32), 300, 200),
        (5.0, (64,64,8), 300, 150),
        (5.0, (32,32,32), 600, 200),
        (5.0, (64,64,8), 600, 150),
        (2.5, (32,32,32), 300, 200),
        (2.5, (64,64,8), 300, 150),
        (5.0, (128, 128, 2), 300, 100),
        (5.0, (128, 128, 2), 600, 100),
]:
    print("Run:", alpha, patch_shape, num_patches, batch_size)
    train_dataset = NewSdfVoxelDataset(us_grid_paths[:train_to], sdf_grid_paths[:train_to],
                                       mesh_paths[:train_to], num_patches_per_thyroid=num_patches,
                                       ultrasound_patches_shape=patch_shape, sdf_patches_shape=patch_shape)
    val_dataset = NewSdfVoxelDataset(us_grid_paths[train_to:val_to], sdf_grid_paths[train_to:val_to],
                                     mesh_paths[train_to:val_to], num_patches_per_thyroid=num_patches,
                                     ultrasound_patches_shape=patch_shape, sdf_patches_shape=patch_shape)
    
    torch.cuda.empty_cache()
    train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=80, device="cuda",
          reshuffle_samples=True, batch_size=batch_size, tensorboard=True,loss_type='weightedSoftMarginTriplet',
          data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": alpha},
          optimizer_params= {"lr": 1e-5},
          ultrasound_patches_shape=patch_shape,
          sdf_patches_shape=patch_shape,
          negative_sample_from_p_furthest=0.5,
     )
    torch.cuda.empty_cache()
# Out:
# Run: 5.0 (128, 128, 1) 300 150
# /data/dilab_data/Thyroid Registration/Partial Registration/SdfVoxelMatching/ssm_thyroid_dataset_originalmethod.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   us_patch_shape = torch.tensor(us_patch_shape)
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...
#   0%|          | 0/36 [00:00<?, ?it/s]
# Run: 5.0 (128, 128, 2) 600 100
# ...
#   0%|          | 0/72 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.5/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 300
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.2)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.2)

# %%
## Experiment 2      SSM with std0.5

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=300, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet', data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std1/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 300
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.2)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.2)
# Out:
# /data/dilab_data/Thyroid Registration/Partial Registration/SdfVoxelMatching/ssm_thyroid_dataset.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   us_patch_shape = torch.tensor(us_patch_shape)

# %%
## Experiment 3     SSM with std 1

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=300, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet', data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.5/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.2)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.2)
# Out:
# /data/dilab_data/Thyroid Registration/Partial Registration/SdfVoxelMatching/ssm_thyroid_dataset.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   us_patch_shape = torch.tensor(us_patch_shape)

# %%
## Experiment 4      SSM with std0.5, changed num_patches to 400

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=300, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet', data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.5/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.8)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.8)

# %%
## Experiment 5      SSM with std0.5, furthest to 0.8, check if it worked

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=300, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet',negative_sample_from_p_furthest = 0.8, data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.5/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.5)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.5)
# Out:
# /data/dilab_data/Thyroid Registration/Partial Registration/SdfVoxelMatching/ssm_thyroid_dataset.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   us_patch_shape = torch.tensor(us_patch_shape)

# %%
## Experiment 6      SSM with std 0.5, furthest to 0.5

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet',negative_sample_from_p_furthest = 0.5, data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.05/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.5)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.5)
# Out:
# /data/dilab_data/Thyroid Registration/Partial Registration/SdfVoxelMatching/ssm_thyroid_dataset.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   us_patch_shape = torch.tensor(us_patch_shape)

# %%
## Experiment 7      SSM with std 0.05, furthest to 0.5

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet',negative_sample_from_p_furthest = 0.5, data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std1/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.5)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.5)

# %%
## Experiment 8      SSM with std 1, furthest to 0.5

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet',negative_sample_from_p_furthest = 0.5, data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf_foronlymean"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf_foronlymean"

sdf_index_range_train = range(0, 1)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.5)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(32,32,32), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.5)

# %%
## Experiment 9     meanshape, meanshape ran 30.11 around 23:40

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet',negative_sample_from_p_furthest = 0.5, data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.05/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(64,64,8), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.5)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(64,64,8), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.5)
# Out:
# /data/dilab_data/Thyroid Registration/Partial Registration/SdfVoxelMatching/ssm_thyroid_dataset.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   us_patch_shape = torch.tensor(us_patch_shape)

# %%
## Experiment 10      SSM with std 0.05, furthest to 0.5, thinner slices ran 01.12. 09:07

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda", reshuffle_samples=True, batch_size=200,ultrasound_patches_shape = (64, 64, 8),
                tensorboard=True,loss_type='weightedSoftMarginTriplet',negative_sample_from_p_furthest = 0.5, data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
us_dir = f"/home/dilab/dilab_data/data"

us_index_range_train = range(0, 24, 2)
us_index_range_val = range(24, 28 , 2)

us_paths_train = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_train]
us_paths_val = [f"{us_dir}/{str(us_index)}.nii" for us_index in us_index_range_val]


sdf_dir_train = f"/home/dilab/dilab_data/data/data_ssmsdf/std0.05/sdf_train"
sdf_dir_val = f"/home/dilab/dilab_data/data/data_ssmsdf/meansdf"

sdf_index_range_train = range(0, 500)
sdf_index_range_val = range(0, 1)

sdf_paths_train = [f"{sdf_dir_train}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_train]
sdf_paths_val = [f"{sdf_dir_val}/SSMsample{str(sdf_index)}sdf" for sdf_index in sdf_index_range_val]


num_patches_per_thyroid = 400
train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_train}",  ultrasound_patches_shape=(128,128,2), sdf_patches_shape=(32,32,32),negative_sample_from_p_furthest=0.5)
val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, num_patches_per_thyroid, sdf_dir=f"{sdf_dir_val}",  ultrasound_patches_shape=(128,128,2), sdf_patches_shape=(32,32,32), negative_sample_from_p_furthest=0.5)

# %%
## Experiment 11      SSM with std 0.05, furthest to 0.5, thinnnnneeeerrrr slices

torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda", reshuffle_samples=True, batch_size=200,ultrasound_patches_shape = (128,128,2),
                tensorboard=True,loss_type='weightedSoftMarginTriplet',negative_sample_from_p_furthest = 0.5, data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=500, device="cuda", reshuffle_samples=True, batch_size=200, tensorboard=True,loss_type='weightedSoftMarginTriplet', data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/26 [00:00<?, ?it/s]

# %%
model_path = 'saves/model_Nov09_10-57-34__lr=0.001_batchSize=200_epochs=200_embeddingSize=128_usPatch=32x32x32_sdfPatch=32x32x32_normalized_reshuffle_pFurthest=0.2_loss=weightedSoftMarginTriplet(alpha=1.0)_embDist.obj'

model = torch.load(model_path)
if isinstance(model, torch.nn.parallel.DataParallel):
    model = model.module

# %%
# Experiment 1: Triplet loss
torch.cuda.empty_cache()
trainer = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda", reshuffle_samples=True, batch_size=200, model=model, tensorboard=True,loss_type='weightedSoftMarginTriplet', data_parallel_gpu_ids=[0,1],stopping_patience=0,loss_params = {"alpha": 1.0},optimizer_params= {"lr": 1e-5})
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/26 [00:00<?, ?it/s]

# %%
# Experiment 1: Triplet loss, less SSM samples (20), 10 / 4/ 2 split
torch.cuda.empty_cache()
model = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=110, device="cuda:1", reshuffle_samples=True, batch_size=128, tensorboard=True,loss_type='weightedSoftMarginTriplet')
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# Experiment 1: JUST FOR TESTING TRAINING = VALIDATION
torch.cuda.empty_cache()
model = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=110, device="cuda:1", reshuffle_samples=True, batch_size=128, tensorboard=True,loss_type='weightedSoftMarginTriplet')
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# Experiment 1: changed indexs of train / val set
torch.cuda.empty_cache()
model = train(train_dataset=train_dataset, val_dataset=val_dataset, epochs=110, device="cuda:1", reshuffle_samples=True, batch_size=128, tensorboard=True,loss_type='weightedSoftMarginTriplet')
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# Experiment 1: Soft assignment loss
model = torch.load("saves/best_model_Nov11_21-11-10__lr=1e-05_batchSize=200_epochs=800_embeddingSize=128_usPatch=32x32x32_sdfPatch=32x32x32_normalized_reshuffle_pFurthest=0.2_loss=weightedSoftMarginTriplet(alpha=1.0)_embDist.obj").module
torch.cuda.empty_cache()
# small_num_patches_per_thyroid = 2
# train_dataset = SSMvoxelDataset(us_paths_train, sdf_paths_train, small_num_patches_per_thyroid, sdf_dir=f"{sdf_dir}/sdf_train")
# val_dataset = SSMvoxelDataset(us_paths_val, sdf_paths_val, small_num_patches_per_thyroid, sdf_dir=f"{sdf_dir}/sdf_mean")
model = train(model=model, train_dataset=train_dataset, val_dataset=val_dataset, epochs=200, device="cuda:0", reshuffle_samples=True, batch_size=64, tensorboard=True, 
              dot_product_similarity=False, normalize_embeddings=True, 
              loss_type='softAssignment', loss_params={"exponentBeta": 0.001}, data_parallel_gpu_ids=[0,1],
            optimizer_params = {"lr": 1e-7},)
torch.cuda.empty_cache()
# Out:
# ...
#   0%|          | 0/65 [00:00<?, ?it/s]
